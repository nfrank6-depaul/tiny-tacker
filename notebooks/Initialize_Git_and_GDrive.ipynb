# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Connect my repo and initialize git
# !cd "/content/drive/My Drive/tiny_tackers" && git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/My Drive/tiny_tackers/.git/

# %%
# Specify Origin
# !cd "/content/drive/My Drive/tiny_tackers" && git remote add origin https://github.com/nfrank6-depaul/tiny-tackers.git

# %%
# Push Repo to Git
# !cd "/content/drive/My Drive/tiny_tackers" && git add .
# !cd "/content/drive/My Drive/tiny_tackers" && git commit -m "Initial commit"
# !cd "/content/drive/My Drive/tiny_tackers" && git push -u origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@95749ef28497.(none)')
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/nfrank6-depaul/tiny-tackers.git'

# %%
# !git config --global user.name "Nicole Frank"
# !git config --global user.email "YOUR_GITHUB_EMAIL@example.com"
